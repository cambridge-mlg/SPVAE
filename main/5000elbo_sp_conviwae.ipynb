# %%
import glob
import pickle
import matplotlib.pyplot as plt
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import sys
import pandas as pd
ROOT_DIR = os.path.abspath("..")
sys.path.append(ROOT_DIR)

# %%
from scripts.sp_conviwae import get_evaluation

# %%
save_dir = "sp_conviwae/mnist_perturbed/-1/1557053671/"
get_evaluation(save_dir, {'take_frac':1, 'kernel_size':(3,3), 'data_dir':os.path.join(ROOT_DIR, "data")})
# Out:
# mnist
# WARNING:tensorflow:From /Code/SPVAE/data/read_dataset.py:63: shuffle_and_repeat (from tensorflow.contrib.data.python.ops.shuffle_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.shuffle_and_repeat(...)`.
# 128 10000.0 10000.0
# start leaf gather
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf46/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf46/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf46/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf46/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf46/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf46/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf46/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf46/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf88/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf88/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf88/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf88/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf88/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf88/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf88/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf88/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf90/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf90/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf90/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf90/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf90/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf90/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf90/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf90/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf51/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf51/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf51/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf51/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf51/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf51/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf51/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf51/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf13/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf13/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf13/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf13/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf13/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf13/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf13/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf13/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf91/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf91/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf91/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf91/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf91/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf91/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf91/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf91/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf93/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf93/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf93/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf93/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf93/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf93/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf93/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf93/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf55/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf55/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf55/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf55/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf55/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf55/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf55/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf55/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf57/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf57/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf57/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf57/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf57/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf57/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf57/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf57/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf18/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf18/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf18/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf18/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf18/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf18/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf18/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf18/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf58/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf58/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf58/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf58/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf58/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf58/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf58/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf58/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf63/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf63/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf63/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf63/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf63/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf63/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf63/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf63/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf97/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf97/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf97/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf97/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf97/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf97/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf97/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf97/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf99/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf99/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf99/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf99/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf99/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf99/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf99/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf99/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf76/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf76/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf76/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf76/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf76/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf76/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf76/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf76/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf81/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf81/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf81/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf81/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf81/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf81/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf81/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf81/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# mean_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# sigma_activation: (?, ?, 7, 7, 1)
# start traversal
# end traversal
# 24 partitions, 24 scopes
# 32 partitions, 16 scopes
# 42 partitions, 17 scopes
# 36 partitions, 12 scopes
# 24 partitions, 6 scopes
# 16 partitions, 4 scopes
# 20 partitions, 4 scopes
# 6 partitions, 1 scopes
# Building SPN took 30.854202270507812  seconds
# In total, there are 32 leaf nodes, 167 sum nodes, and 800 product nodes
# INFO:tensorflow:Restoring parameters from sp_conviwae/mnist_perturbed/-1/1557053671/saved_models/model.ckpt-20480
# 999
# 2702.3499

# %%
save_dir = "sp_conviwae/mnist_discrete/-1/1557348275/"
get_evaluation(save_dir, {'take_frac':1, 'kernel_size':(3,3), 'data_dir':os.path.join(ROOT_DIR, "data")})
# Out:
# mnist
# 128 10000.0 10000.0
# start leaf gather
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf13/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf13/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf13/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf13/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf13/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf13/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf13/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf13/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf13/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf13/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf13/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf13/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf76/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf76/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf76/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf76/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf76/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf76/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf76/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf76/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf76/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf76/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf76/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf76/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf81/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf81/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf81/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf81/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf81/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf81/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf81/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf81/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf81/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf81/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf81/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf81/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf55/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf55/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf55/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf55/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf55/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf55/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf55/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf55/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf55/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf55/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf55/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf55/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf57/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf57/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf57/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf57/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf57/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf57/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf57/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf57/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf57/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf57/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf57/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf57/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf58/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf58/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf58/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf58/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf58/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf58/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf58/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf58/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf58/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf58/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf58/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf58/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf63/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf63/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf63/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf63/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf63/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf63/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf63/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf63/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf63/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf63/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf63/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf63/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf18/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf18/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf18/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf18/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf18/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf18/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf18/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf18/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf18/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf18/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf18/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf18/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf46/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf46/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf46/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf46/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf46/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf46/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf46/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf46/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf46/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf46/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf46/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf46/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf88/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf88/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf88/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf88/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf88/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf88/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf88/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf88/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf88/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf88/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf88/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf88/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf90/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf90/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf90/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf90/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf90/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf90/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf90/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf90/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf90/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf90/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf90/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf90/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf51/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf51/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf51/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf51/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf51/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf51/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf51/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf51/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf51/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf51/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf51/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf51/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf91/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf91/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf91/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf91/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf91/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf91/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf91/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf91/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf91/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf91/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf91/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf91/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf93/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf93/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf93/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf93/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf93/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf93/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf93/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf93/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf93/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf93/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf93/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf93/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf97/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf97/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf97/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf97/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf97/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf97/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf97/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf97/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf97/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf97/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf97/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf97/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf99/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf99/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf99/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf99/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf99/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf99/0_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, 49)
# (?, 7, 7, 1)
# (?, 7, 7, 4)
# (?, 7, 7, 8)
# (?, 392)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf99/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf99/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 392)
# (?, 7, 7, 8)
# (?, 7, 7, 4)
# (<tf.Variable 'Leaf99/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf99/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 4)
# (<tf.Variable 'Leaf99/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf99/1_1/strided_slice:0' shape=() dtype=int32>, 7, 7, 1)
# (?, ?, 7, 7, 1)
# (?, ?, 7, 7, 1)
# start traversal
# end traversal
# 24 partitions, 24 scopes
# 32 partitions, 16 scopes
# 42 partitions, 17 scopes
# 36 partitions, 12 scopes
# 24 partitions, 6 scopes
# 16 partitions, 4 scopes
# 20 partitions, 4 scopes
# 6 partitions, 1 scopes
# Building SPN took 9.696862697601318  seconds
# In total, there are 32 leaf nodes, 167 sum nodes, and 800 product nodes
# INFO:tensorflow:Restoring parameters from sp_conviwae/mnist_discrete/-1/1557348275/saved_models/model.ckpt-26880
# 999
# -926.5159

# %%
save_dir = "sp_conviwae/svhn_perturbed/-1/1557172342/"
get_evaluation(save_dir, {'take_frac':1, 'kernel_size':(3,3), 'data_dir':os.path.join(ROOT_DIR, "data")})
# Out:
# svhn
# 128 26032.0 26032.0
# start leaf gather
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf88/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf88/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf88/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf88/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf88/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf88/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf88/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf88/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf90/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf90/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf90/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf90/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf90/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf90/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf90/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf90/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf18/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf18/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf18/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf18/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf18/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf18/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf18/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf18/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf91/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf91/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf91/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf91/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf91/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf91/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf91/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf91/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf93/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf93/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf93/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf93/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf93/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf93/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf93/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf93/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf13/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf13/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf13/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf13/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf13/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf13/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf13/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf13/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf97/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf97/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf97/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf97/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf97/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf97/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf97/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf97/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf99/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf99/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf99/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf99/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf99/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf99/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf99/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf99/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf51/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf51/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf51/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf51/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf51/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf51/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf51/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf51/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf76/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf76/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf76/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf76/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf76/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf76/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf76/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf76/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf81/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf81/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf81/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf81/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf81/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf81/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf81/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf81/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf55/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf55/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf55/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf55/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf55/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf55/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf55/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf55/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf57/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf57/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf57/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf57/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf57/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf57/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf57/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf57/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf58/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf58/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf58/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf58/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf58/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf58/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf58/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf58/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf46/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf46/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf46/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf46/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf46/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf46/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf46/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf46/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf63/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf63/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf63/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf63/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Leaf63/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf63/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf63/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf63/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# start traversal
# end traversal
# 24 partitions, 24 scopes
# 32 partitions, 16 scopes
# 42 partitions, 17 scopes
# 36 partitions, 12 scopes
# 24 partitions, 6 scopes
# 16 partitions, 4 scopes
# 20 partitions, 4 scopes
# 6 partitions, 1 scopes
# Building SPN took 9.595411777496338  seconds
# In total, there are 32 leaf nodes, 167 sum nodes, and 800 product nodes
# INFO:tensorflow:Restoring parameters from sp_conviwae/svhn_perturbed/-1/1557172342/saved_models/model.ckpt-20224
# 2602
# 2101.4128

# %%
save_dir = "sp_conviwae/svhn_discrete/-1/1557277235/"
get_evaluation(save_dir, {'take_frac':1, 'kernel_size':(3,3), 'data_dir':os.path.join(ROOT_DIR, "data")})
# Out:
# svhn
# 128 26032.0 26032.0
# start leaf gather
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 64)
# (?, 25)
# <tf.Variable 'Lea
activation: (?, ?, 8, 8, 1)
# mean_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# sigma_activation: (?, ?, 8, 8, 1)
# start traversal
# end traversal
# 24 partitions, 24 scopes
# 32 partitions, 16 scopes
# 42 partitions, 17 scopes
# 36 partitions, 12 scopes
# 24 partitions, 6 scopes
# 16 partitions, 4 scopes
# 20 partitions, 4 scopes
# 6 partitions, 1 scopes
# Building SPN took 6.336484432220459  seconds
# In total, there are 32 leaf nodes, 167 sum nodes, and 800 product nodes
# INFO:tensorflow:Restoring parameters from sp_conviwae/cifar10_perturbed/-1/1557158626/saved_models/model.ckpt-25984
# 999
# 1397.3726

# %%
save_dir = "sp_conviwae/cifar10_discrete/-1/1557460207/"
get_evaluation(save_dir, {'take_frac':1, 'kernel_size':(3,3), 'data_dir':os.path.join(ROOT_DIR, "data")})
# Out:
# cifar10
# 128 10000.0 10000.0
# start leaf gather
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf97/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf97/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf97/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf97/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf97/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf97/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf97/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf97/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf97/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf97/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf97/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf97/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf99/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf99/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf99/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf99/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf99/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf99/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf99/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf99/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf99/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf99/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf99/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf99/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf13/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf13/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf13/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf13/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf13/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf13/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf13/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf13/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf13/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf13/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf13/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf13/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf57/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf57/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf57/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf57/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf57/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf57/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf57/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf57/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf57/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf57/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf57/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf57/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf58/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf58/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf58/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf58/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf58/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf58/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf58/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf58/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf58/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf58/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf58/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf58/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf63/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf63/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf63/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf63/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf63/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf63/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf63/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf63/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf63/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf63/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf63/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf63/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf18/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf18/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf18/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf18/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf18/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf18/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf18/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf18/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf18/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf18/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf18/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf18/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf46/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf46/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf46/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf46/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf46/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf46/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf46/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf46/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf46/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf46/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf46/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf46/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf88/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf88/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf88/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf88/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf88/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf88/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf88/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf88/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf88/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf88/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf88/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf88/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf90/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf90/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf90/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf90/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf90/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf90/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf90/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf90/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf90/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf90/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf90/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf90/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf51/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf51/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf51/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf51/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf51/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf51/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf51/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf51/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf51/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf51/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf51/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf51/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf91/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf91/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf91/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf91/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf91/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf91/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf91/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf91/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf91/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf91/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf91/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf91/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf93/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf93/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf93/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf93/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf93/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf93/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf93/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf93/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf93/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf93/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf93/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf93/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf76/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf76/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf76/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf76/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf76/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf76/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf76/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf76/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf76/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf76/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf76/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf76/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf81/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf81/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf81/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf81/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf81/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf81/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf81/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf81/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf81/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf81/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf81/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf81/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf55/0/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf55/0_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf55/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf55/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf55/0/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf55/0_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, 64)
# (?, 8, 8, 1)
# (?, 8, 8, 4)
# (?, 8, 8, 8)
# (?, 512)
# (?, 32)
# (?, 25)
# <tf.Variable 'Leaf55/1/Variable:0' shape=() dtype=int32_ref> Tensor("Leaf55/1_1/strided_slice:0", shape=(), dtype=int32) 25
# zs (?, ?, 25)
# (?, ?, 25)
# (?, ?, 512)
# (?, 8, 8, 8)
# (?, 8, 8, 4)
# (<tf.Variable 'Leaf55/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf55/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 4)
# (<tf.Variable 'Leaf55/1/Variable:0' shape=() dtype=int32_ref>, <tf.Tensor 'Leaf55/1_1/strided_slice:0' shape=() dtype=int32>, 8, 8, 1)
# (?, ?, 8, 8, 1)
# (?, ?, 8, 8, 1)
# start traversal
# end traversal
# 24 partitions, 24 scopes
# 32 partitions, 16 scopes
# 42 partitions, 17 scopes
# 36 partitions, 12 scopes
# 24 partitions, 6 scopes
# 16 partitions, 4 scopes
# 20 partitions, 4 scopes
# 6 partitions, 1 scopes
# Building SPN took 4.309841632843018  seconds
# In total, there are 32 leaf nodes, 167 sum nodes, and 800 product nodes
# INFO:tensorflow:Restoring parameters from sp_conviwae/cifar10_discrete/-1/1557460207/saved_models/model.ckpt-25856
# 999
# -4562.249
